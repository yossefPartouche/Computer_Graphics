# %% [markdown]
# ## Uniquely Defining Affine Transformation
# ##### Objective:
# 1. How many mappings of 2D points are needed to uniquely define a 2D Affine Transformation

# %% [markdown]
# Currently we know that given an Affine Transformation $T$, the for every point $p$ we can find the traget point $p'$ by applying $T(p) = p'$
# Suppose now we're given a set of points $\{p_1, p_2, \ ... p_k\}$ and their resulting mappings $\{p'_1, p'_2, \ ... p'_k\}$
#
# 1. Can we find the mapping $T$ that produces these results?
# 2. How many points are needed to uniquely define a 2D affine transformation?
# - Meaning how many point and transformed points do we need to understand the tyes of transformation that occured
# 3. Can we define an affine transformation for any mapping of any number of k points?
#
# ---

# %% [markdown]
# ### Answer to Q2
#
# How many free parameters define a 2D Affine transformation (How many can be changed/are variables?)
#
#  \begin{pmatrix} a_{11} & a_{12} & v_x \\ a_{21} & a_{22} & v_{y} \\ 0 & 0 & 1 \end{pmatrix}
#
# A. **Answer: 6**
#
# $\{a_{11}, a_{12}, a_{21}, a_{22}, \vec{v_x}, \vec{v_y}\}$
# These unknowns denote the **degrees of freedom**.
#
# #### Details:
#
# - Every mapping of a point add two constraints to our problem
#     1. We know that $x_1$ is mapped to $x'_1$
#     2. We know that $y_1$ is mapped to $y'_1$
# - We take the general form of the Affine tranformation and multiply it with our known homogeous form of $p$ and equate to our known homogeous form of $p'$
# $$p' =  \begin{pmatrix} a_{11} & a_{12} & v_x \\ a_{21} & a_{22} & v_{y} \\ 0 & 0 & 1 \end{pmatrix}\begin{pmatrix} x \\ y \\ 1\end{pmatrix}$$
# - We then obtain two equations (the two constraints)
# $$ a_{11}x_1 + a_{12}y_1 + v_x = x'_{1} $$
# $$ a_{21}x_1 + a_{22}y_1 + v_y = y'_1 $$
#
# $ \text{To uniquely define an affine transformation in 2D we need a mapping of 3 points } p_1, p_2, p_3$
#
# - $\text{Providing 6 Linear equations}$
#
# $$
# \begin{aligned}
# a_{11}x_1 + a_{12}y_1 + v_x &= x'_1 \\
# a_{21}x_1 + a_{22}y_1 + v_y &= y'_1 \\
# a_{11}x_2 + a_{12}y_2 + v_x &= x'_2 \\
# a_{21}x_2 + a_{22}y_2 + v_y &= y'_2 \\
# a_{11}x_3 + a_{12}y_3 + v_x &= x'_3 \\
# a_{21}x_3 + a_{22}y_3 + v_y &= y'_3
# \end{aligned}
# \quad \Rightarrow \quad
# \begin{pmatrix}
# x_1 & 0 & y_1 & 0 & 1 & 0 \\
# 0 & x_1 & 0 & y_1 & 0 & 1 \\
# x_2 & 0 & y_2 & 0 & 1 & 0 \\
# 0 & x_2 & 0 & y_2 & 0 & 1 \\
# x_3 & 0 & y_3 & 0 & 1 & 0 \\
# 0 & x_3 & 0 & y_3 & 0 & 1
# \end{pmatrix}
# \begin{pmatrix}
# a_{11} \\
# a_{21} \\
# a_{12} \\
# a_{22} \\
# v_x \\
# v_y
# \end{pmatrix}
# =
# \begin{pmatrix}
# x'_1 \\
# y'_1 \\
# x'_2 \\
# y'_2 \\
# x'_3 \\
# y'_3
# \end{pmatrix}
# $$
#
# - Since we have 6 unknowns and each point defines two constriants, we need the mapping of exactly 3 points to uniquely define an affine transformation in 2D, to uniquely define an affine transformation. Since this will provide 6 linear equations to solve for the unknowns.
#
#
# ---

# %% [markdown]
# ### Answer to Q3
#
# we'll change the question, what if we have a mapping of more than three points?
#
# This is an **overconstraint** since we have less degrees of freedom than the constraining conditions:
#
# So No Solution to the problem (USUALLY).
#
# So we approximate for any set of k-points: (Not for the scope)
#
# ---

# %% [markdown]
# ### Conclusion
#
# If we have 3 points that are not collinear then we can form a triangle plane:
# - Choose one point to be the origin.
# - 2 other points define vectors relative to the origin.
# - These two vectors can define a base for the underlying vector space (Meaning they define an Affine Coordinate system).
#
#
# <p align="center">
# <img src="image_U6/Screenshot 2025-06-26 at 10.36.35.png" height="300" width="300"/>
# <img src="image_U6/Screenshot 2025-06-26 at 10.37.06.png" height="300" width="300"/>
# <img src="image_U6/Screenshot 2025-06-26 at 10.37.23.png" height="300" width="300"/>
# <p/>
#
# With this we can use Affine Transformation to map from one Affine Coordinate system to another Affine Coordinate system.
# This is very useful in the later chapters.
