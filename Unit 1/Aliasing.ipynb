# %% [markdown]
# #### Aliasing
# #### Objective
# What can happen if we don't uphold the necessary condition of the nyquist-shannon theorem

# %% [markdown]
# #### Low smapling rate on 1D functions
#
# **Assume that we know the exact type of function, to strengthen the point of the theroem**
#
# <img src="image_U1/ourFun.png" height="300" width="300"/>
#
# If our function is a sinusoidal wave, which is determined by its frequency, assume that the amplitude is 1 and the phase is 0.
# Assume we decide on an interval to sample this function.
# Since we know that the function is sine wave, we only need to determine the correct freq. to be able to reconstruct the function.
# - We'll choose sample points at a uniform interval based.
# - forget the function
# - As we know the function we are aiming to match, we'll try to recreate a sine function.
#
#
# <img src="image_U1/st1.png" height="300" width="300"/>
# <img src="image_U1/st2.png" height="300" width="300"/>
# <img src="image_U1/st3.png" height="300" width="300"/>
#
# Note that the result isn't the match, this is because we didn't choose enough sampling points for the frequency of the function.
#
# <img src="image_U1/st4.png" height="300" width="300"/>
# <img src="image_U1/st5.png" height="300" width="300"/>
#
# and we can exaggerate to see how far off we can be.
#
# This is what is known as "Aliasing" (An Imposter of the true function).
# Aliasing : "Where 2 functions cannot be distinguished based on a **specific** sampling."
#
#
# <img src="image_U1/st6.png" height="300" width="300"/>
# <img src="image_U1/st8.png" height="300" width="300"/>
# <img src="image_U1/st69.png" height="300" width="300"/>
# <img src="image_U1/st7.png" height="300" width="300"/>

# %% [markdown]
# ##### Question
# A signal that has bounded frequency is called bandlimited. Assume that you can bound the highest frequency of a signal to K hertz. What would be the sampling rate needed to reconstruct it?
#
# ##### Answer
# You would need at least 2K hertz, since "A sinal can be reconstructed from its samples if the roiginal signal has no frequencies **above** half the sampling frequency", (the question was flipped on the theorem).
