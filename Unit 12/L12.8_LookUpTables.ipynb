# %% [markdown]
# ## LookUp Tables in Graphics
#
# - $\text{In texture mapping, vertices of the triangles have (u,v), values rasterisation interpolates these values, into the triangle to define a (u,v) value fo reach pixel, which will be used as an indec to get the color of the pixel of the pixel.}$
#
# ### Objective:
# - $\text{Discuss the applications of lookup tables}$
